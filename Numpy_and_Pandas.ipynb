# %%
import numpy as np
arr=np.array([10,20,30,40,50])
print("Nump array")
print(arr)
# Out:
# Nump array
# [10 20 30 40 50]

# %%
arr[0:3]
# Out:
# array([10, 20, 30])

# %%
arr[-3:-1]
# Out:
# array([30, 40])

# %%
print("Addition:",arr+3)
# Out:
# Addition: [13 23 33 43 53]

# %%
print("Substraction:",arr-3)
# Out:
# Substraction: [ 7 17 27 37 47]

# %%
print("multiplication:",arr*5)
# Out:
# multiplication: [ 50 100 150 200 250]

# %%
print("Divisio:",arr/5)
# Out:
# Divisio: [ 2.  4.  6.  8. 10.]

# %%
print("Array:",arr)
Reshape=arr.reshape(5,1)
print(Reshape)
# Out:
# Array: [10 20 30 40 50]
# [[10]
#  [20]
#  [30]
#  [40]
#  [50]]

# %%
print("Array:",arr)
print("Sum:",np.sum(arr))
print("Mean:",np.mean(arr))
print("Max:",np.max(arr))
# Out:
# Array: [10 20 30 40 50]
# Sum: 150
# Mean: 30.0
# Max: 50

# %%
import pandas as pd
data = {
    "name": ["Asha", "Ravi", "Meera", "Karan"],
    "marks":[88,72,91,65],
    "branch": ["CSF", "ECE", "CSE", "ISF"]
}
df = pd.DataFrame(data)
print(df)
# Out:
#     name  marks branch
# 0   Asha     88    CSF
# 1   Ravi     72    ECE
# 2  Meera     91    CSE
# 3  Karan     65    ISF

# %%
print(df["name"])
print(df["marks"])
# Out:
# 0     Asha
# 1     Ravi
# 2    Meera
# 3    Karan
# Name: name, dtype: str
# 0    88
# 1    72
# 2    91
# 3    65
# Name: marks, dtype: int64

# %%
print(df.iloc[0])
# Out:
# name      Asha
# marks       88
# branch     CSF
# Name: 0, dtype: object

# %%
print(df.iloc[3])
# Out:
# name      Karan
# marks        65
# branch      ISF
# Name: 3, dtype: object

# %%
a=len(data)
for i in range (a):
 print(df.iloc[i])
# Out:
# name      Asha
# marks       88
# branch     CSF
# Name: 0, dtype: object
# name      Ravi
# marks       72
# branch     ECE
# Name: 1, dtype: object
# name      Meera
# marks        91
# branch      CSE
# Name: 2, dtype: object

# %%
    print("*")
# Out:
# *

# %%
a='* '
for i in range(-6,0):
    print(i*a)
